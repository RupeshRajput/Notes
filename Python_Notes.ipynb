# %% [markdown]
# # **Python Notes**

# %% [markdown]
# **PIP** :- Pip is a dependency manager help to get third party library from pypi.org

# %% [markdown]
# ##### **Use Print Function**

# %%
# First way print method
print("Hello, World!")
# Out:
# Hello, World!

# %%
# Second way print method
print("""Hello, World!
Hello, World!""")
# Out:
# Hello, World!
# Hello, World!

# %% [markdown]
# #### ----------------------------------------------------------------------

# %% [markdown]
# ##### **Use Separator(sep) Parameter**

# %%
print("Apple","Banana","Cherry")
# Out:
# Apple Banana Cherry

# %%
print("Apple","Banana","Cherry" ,sep=" ")
# Out:
# Apple Banana Cherry

# %%
print("16","Mar","2026",sep="-")
# Out:
# 16-Mar-2026

# %% [markdown]
# #### ----------------------------------------------------------------------
